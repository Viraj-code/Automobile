# %% [markdown]
# <a href="https://colab.research.google.com/github/PrateekTiwari07/Edumania/blob/main/3_prepare_model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Volkswagen Buyout Porche - Announcement 1 and 2
# Volkswagen Dieselgate Scandal - Dieselgate
# BMW => Market Benchmark

# %% [markdown]
# 1 - Import Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")
sns.set()

# %% [markdown]
# 2 - Load Dataset

# %%
df = pd.read_csv("automobile-indexes-preprocessed.csv", index_col=["Date"])
df.index = pd.to_datetime(df.index)
df.head()
# Out:
#                   vol        por        bmw   ret_vol   ret_por   ret_bmw  \
# Date
# 2009-01-29  27.121136  24.616135  10.875431  1.225257 -3.831346 -3.582730
# 2009-01-30  27.065256  25.202362  11.059665 -0.206037  2.381476  1.694036
# 2009-02-02  25.312124  24.194273  10.465377 -6.477426 -3.999979 -5.373471
# 2009-02-03  25.088619  24.091171  10.771433 -0.882996 -0.426141  2.924463
# 2009-02-04  25.731203  24.033892  11.511320  2.561256 -0.237762  6.868977
#
#                sq_vol     sq_por     sq_bmw     q_vol      q_por      q_bmw
# Date
# 2009-01-29   1.501255  14.679210  12.835952  175749.0   629474.0  5951883.0
# 2009-01-30   0.042451   5.671429   2.869756  330777.0  1467863.0  3368505.0
# 2009-02-02  41.957044  15.999828  28.874190  217917.0  1350452.0  4149233.0
# 2009-02-03   0.779682   0.181596   8.552481  210250.0  1183009.0  3953543.0
# 2009-02-04   6.560034   0.056531  47.182844  182653.0  1688343.0  4844579.0

# %%
df.tail()
# Out:
#                    vol        por        bmw   ret_vol   ret_por   ret_bmw  \
# Date
# 2022-05-25  145.440002  71.839996  77.790001  0.000000  0.000000  0.000000
# 2022-05-26  151.339996  73.320000  80.250000  4.056651  2.060138  3.162359
# 2022-05-27  151.339996  73.320000  80.250000  0.000000  0.000000  0.000000
# 2022-05-30  151.339996  73.320000  80.250000  0.000000  0.000000  0.000000
# 2022-05-31  154.679993  76.139999  80.629997  2.206949  3.846153  0.473517
#
#                sq_vol     sq_por     sq_bmw      q_vol      q_por      q_bmw
# Date
# 2022-05-25   0.000000   0.000000   0.000000        0.0        0.0        0.0
# 2022-05-26  16.456421   4.244170  10.000514   884473.0   528086.0  1068788.0
# 2022-05-27   0.000000   0.000000   0.000000        0.0        0.0        0.0
# 2022-05-30   0.000000   0.000000   0.000000        0.0        0.0        0.0
# 2022-05-31   4.870623  14.792896   0.224218  1193371.0  1398660.0  1807592.0

# %% [markdown]
# 3 - Defining Key Dates

# %%
# Starting Date
start_date = "2009-01-29"
# First Official Announcement - Volkswagen Buy 49.9% of Porche
ann_1 = "2009-12-09"
# Second Official Announcement - Volkswagen Buy Rest 51.1% of Porche
ann_2 = "2012-07-05"
# Ending Date
end_date = "2022-05-31"
# Dieselgate
d_gate = "2015-09-20"

# %% [markdown]
# 4 - Plotting Data

# %%
df['vol'][start_date:end_date].plot(figsize=(20, 8), color="red", label="Volkswagen")
df['por'][start_date:end_date].plot(color="green", label="Porche")
df['bmw'][start_date:end_date].plot(color="blue", label="BMW")
plt.legend()
plt.show()

# %%
df['vol'][start_date:ann_1].plot(figsize=(20, 10), color="#33B8FF")
df['por'][start_date:ann_1].plot(color="#49FF3A")
df['bmw'][start_date:ann_1].plot(color="#FEB628")

df['vol'][ann_1:ann_2].plot(color="#1E7EB2")
df['por'][ann_1:ann_2].plot(color="#2FAB25")
df['bmw'][ann_1:ann_2].plot(color="#BA861F")

df['vol'][ann_2:end_date].plot(color="#0E3A52")
df['por'][ann_2:end_date].plot(color="#225414")
df['bmw'][ann_2:end_date].plot(color="#7C5913")

plt.legend(['Volkswagen', 'Porsche', 'BMW'])
plt.show()
